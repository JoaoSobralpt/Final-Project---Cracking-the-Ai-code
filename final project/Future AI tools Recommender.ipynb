# %%
import pandas as pd
futuredf = pd.read_csv('futuredf.csv')
from IPython.display import display, HTML
futuredf.to_csv('futuredf.csv', index=False)

available_categories = futuredf['category'].unique()
category_list = ", ".join(available_categories)

print("Available categories:")
print(category_list)

selected_category = input("Enter the category you're interested in: ")

# Filter 'futuredf' based on the selected category
filtered_df = futuredf[futuredf['category'] == selected_category]

if not filtered_df.empty:
    # Sort filtered_df by upvotes in descending order to get the most upvoted tools
    recommended_tools = filtered_df.sort_values(by='upvotes', ascending=False)

    # Create an HTML string to display the tool names, descriptions, upvotes, and images
    html_str = ""
    for index, row in recommended_tools.iterrows():
        tool_name = row['tool_name']
        tool_description = row['tool_description']
        upvotes = row['upvotes']
        tool_image_url = row['tool_mage_url']
        # Add the tool information and image to the HTML string
        html_str += f"<p><strong>{tool_name}</strong> - {tool_description}<br>Upvotes: {upvotes}</p>"
        html_str += f'<img src="{tool_image_url}" alt="{tool_name}" style="max-width:300px;"/><br><br>'

    # Display the HTML string
    display(HTML(html_str))
else:
    print(f"No tools found in the '{selected_category}' category.")
# Out:
# Available categories:
# Productivity, Chat, Generative Art, Image Improvement, Marketing, Copywriting, Music, Video Editing, Podcasting, AI Detection, Research, Text-To-Video, Generative Code, For Fun, Self-Improvement, Translation, Avatar, Aggregators, Generative Video, Finance, Speech-To-Text, Inspiration, Gaming, Prompt Guides, Text-To-Speech, Voice Modulation, Social Media, Image Scanning, Motion Capture
# Enter the category you're interested in:  Chat
# <p><strong>Character.AI</strong> - Have chat conversations with AI characters<br>Upvotes: 2327</p><img src="https://global-uploads.webflow.com/63994dae1033718bee6949ce/639ccec738e93f0f4cd39bc8_639bca34ba62963dd710cc16_Character%2520AI.jpeg" alt="Character.AI" style="max-width:300px;"/><br><br><p><strong>Role Model AI</strong> - A platform to create personalized AI assistant.<br>Upvotes: 1504</p><img src="https://global-uploads.webflow.com/63994dae1033718bee6949ce/64237bdf6ce1fc3783cc9060_6420f16f7894bf65c033a5bf_banner.png" alt="Role Model AI" style="max-width:300px;"/><br><br><p><strong>Visus</strong> - Create your own ChatGPT AI<br>Upvotes: 1000</p><img src="https://global-uploads.webflow.com/63994dae1033718bee6949ce/642b1bd4fbd8754a792fc463_kastsHh.png" alt="Visus" style="max-width:300px;"/><br><br><p><strong>Humata</strong> - Upload documents and then ask it questions<br>Upvotes: 968</p><img src="https://global-uploads.webflow.com/63994dae1033718bee6949ce/63e1e4f121408874a4d57fb6_Screenshot-2-6-2023-9.43.06%20PM.png" alt="Humata" style="max-width:300px;"/><br><br><p><strong>ChatGPT (OpenAI)</strong> - Ask any question or prompt to AI - The tool most other writing tools are based on<br>Upvotes: 814</p><img src="https://global-uploads.webflow.com/63994dae1033718bee6949ce/639bc4c3ba62961a34105d77_ChatGPT.jpeg" alt="ChatGPT (OpenAI)" style="max-width:300px;"/><br><br><p><strong>ChatGPT for Search Engines</strong> - Browser extension that adds ChatGPT to search engines<br>Upvotes: 749</p><img src="https://global-uploads.webflow.com/63994dae1033718bee6949ce/63e493e3f470fc257a745ecb_unnamed%20(1).jpg" alt="ChatGPT for Search Engines" style="max-width:300px;"/><br><br><p><strong>Godmode</strong> - A ui for chatgpt.<br>Upvotes: 578</p><img src="https://global-uploads.webflow.com/63994dae1033718bee6949ce/643a8c2bb8c0e87f693c5057_godmode-space-logo.png" alt="Godmode" style="max-width:300px;"/><br><br><p><strong>Ask Your PDF</strong> - A tool to summarize and interact with PDF files.<br>Upvotes: 245</p><img src="https://global-uploads.webflow.com/63994dae1033718bee6949ce/6413eb4bf481f632df14ca4a_logo512.png" alt="Ask Your PDF" style="max-width:300px;"/><br><br><p><strong>Bing</strong> - Bing Chatbot With ChatGPT<br>Upvotes: 220</p><img src="https://global-uploads.webflow.com/63994dae1033718bee6949ce/63e949eed1100c02aeb8c117_th.jpeg" alt="Bing" style="max-width:300px;"/><br><br><p><strong>Perplexity for Chrome</strong> - A Google Chrome Extension of perplexity.ai.<br>Upvotes: 209</p><img src="https://global-uploads.webflow.com/63994dae1033718bee6949ce/63f57d9b61231b1ce2c1e712__svi7TAoZXCuiYQC2eQet6BsXDcDmGEq7lEEgqb85sXkAYRdkUcraBiN020ejUl_1Qc782-Cx_potYm83oZb4pP_%3Dw128-h128-e365-rj-sc0x00ffffff.jpeg" alt="Perplexity for Chrome" style="max-width:300px;"/><br><br><p><strong>Character GPT</strong> - Generates interactive AI Characters from a description<br>Upvotes: 194</p><img src="https://global-uploads.webflow.com/63994dae1033718bee6949ce/63c71500fc9435ff38f13be6_Screenshot-1-17-2023-1.19.06%20PM.png" alt="Character GPT" style="max-width:300px;"/><br><br><p><strong>Perplexity AI</strong> - Combines GPT 3.5 and Bing to answer questions<br>Upvotes: 178</p><img src="https://global-uploads.webflow.com/63994dae1033718bee6949ce/63be4ba1464ebd6e73bc9f60_63b72d3fd4286272319fbe3c_Screenshot%2520(128).png" alt="Perplexity AI" style="max-width:300px;"/><br><br><p><strong>Banter AI</strong> - A platform to call chat with over 100 celebrities.<br>Upvotes: 171</p><img src="https://global-uploads.webflow.com/63994dae1033718bee6949ce/642da0a1d95b8b3aeb24c307_banterai-app-logo.png" alt="Banter AI" style="max-width:300px;"/><br><br><p><strong>Minigpt-4</strong> - A tool to upload images and chat with them with natural language.<br>Upvotes: 157</p><img src="https://global-uploads.webflow.com/63994dae1033718bee6949ce/644096e9b2e86239972ebb59_online_demo.png" alt="Minigpt-4" style="max-width:300px;"/><br><br><p><strong>ChatFast</strong> - A tool to create  ...
